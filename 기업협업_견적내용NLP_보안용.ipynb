# %% [markdown]
# <a href="https://colab.research.google.com/github/senasung37/startup_project/blob/main/%EA%B8%B0%EC%97%85%ED%98%91%EC%97%85_%EA%B2%AC%EC%A0%81%EB%82%B4%EC%9A%A9NLP_%EB%B3%B4%EC%95%88%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 불러오기

# %%
#라이브러리
import pandas as pd
import requests
import numpy as np

#nlp 라이브러리
import re
import nltk
import spacy
from spacy.tokenizer import Tokenizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
# 견적서 파일 df로 불러오기
df = pd.read_excel('견적서_변형.xlsx')
df.head(3)
# Out:
#          유저명  사업자 여부 클라이언트       총 금액        항목명           규격    수량       단가  \
# 0  Lee Jeong       1   김민찬  1500000.0    영문기사 작성          NaN     1  1000000
# 1        이정훈       0  클래스랩  1125000.0  신문사 기사 발행          NaN     5   150000
# 2      siren       1   이운형  8250000.0     김치찌개 팩  구수한맛50g*2ea  1000     2500
#
#       분류  세부분류   메모  Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0   비즈니스  문서작업  NaN          NaN          NaN         NaN
# 1   비즈니스  문서작업  NaN          NaN          NaN         NaN
# 2  건강/미용    푸드  NaN          NaN          NaN         NaN

# %%
df = df.iloc[:, :10]
df.head(3)
# Out:
#          유저명  사업자 여부 클라이언트       총 금액        항목명           규격    수량       단가  \
# 0  Lee Jeong       1   김민찬  1500000.0    영문기사 작성          NaN     1  1000000
# 1        이정훈       0  클래스랩  1125000.0  신문사 기사 발행          NaN     5   150000
# 2      siren       1   이운형  8250000.0     김치찌개 팩  구수한맛50g*2ea  1000     2500
#
#       분류  세부분류
# 0   비즈니스  문서작업
# 1   비즈니스  문서작업
# 2  건강/미용    푸드

# %% [markdown]
# #데이터 전처리

# %% [markdown]
# ## 데이터 클리닝

# %%
#테스트 행 삭제
df = df[df["분류"].str.contains('테스트') == False]
df
# Out:
#            유저명  사업자 여부  클라이언트       총 금액          항목명           규격    수량  \
# 0    Lee Jeong       1    김민찬  1500000.0      영문기사 작성          NaN     1
# 1          이정훈       0   클래스랩  1125000.0    신문사 기사 발행          NaN     5
# 2        siren       1    이운형  8250000.0       김치찌개 팩  구수한맛50g*2ea  1000
# 3        James       1    자운재  8250000.0     블루베리 액기스   얼큰 50g*2ea  1000
# 4          강예호       0     고객   600000.0         문서작업           매절   100
# ..         ...     ...    ...        ...          ...          ...   ...
# 396        허준오       1  미디어세상  9000000.0  양천구청 캐릭터 제작      타이틀(3D)     1
# 397        허준오       1  미디어세상  4200000.0    미디어 예술상회         로고 제작     1
# 398        허준오       1  미디어세상  4200000.0    미디어 예술상회       타이틀/15초     1
# 399        허준오       0    오유정  4500000.0   MBC 방송 타이틀       FHD15초     1
# 400        황수현       1    IOU  4275000.0          관리기    AMC-880SM     1
#
#           단가       분류     세부분류
# 0    1000000     비즈니스     문서작업
# 1     150000     비즈니스     문서작업
# 2       2500    건강/미용       푸드
# 3       3000    건강/미용       푸드
# 4       4000     비즈니스     문서작업
# ..       ...      ...      ...
# 396  6000000  상업용 디자인  상업용 디자인
# 397   300000  상업용 디자인  상업용 디자인
# 398  2500000      미디어      미디어
# 399  3000000      미디어      미디어
# 400  2850000    기기/기술  전자/소형설비
#
# [332 rows x 10 columns]

# %%
#함수-특수기호, 공백제거

def clean_text(texts):
  #remove punctuation 
  new_text = re.sub(r'[@%\\*=()/~#&\+á?\xc3\xa1\-\|\.\:\;\!\-\,\_\~\$\'\"]', '',str(texts))

  #remove number
  new_text = re.sub(r'\d+','', str(new_text))
  #remove extra space
  new_text = re.sub(r'\s+', ' ',new_text) 
  #remove spaces
  new_text = re.sub(r'\s+', ' ', new_text) 
  #remove space from start
  new_text = re.sub(r"^\s+", '', new_text) 
  #remove space from the end  
  new_text = re.sub(r'\s+$', '', new_text) 
  #lower case 
  new_text = new_text.lower() 
  #remove Html tags 
  #new_text = re.sub(r'<[^>]+>', '', new_text) 
  return new_text

# %%
#함수 - 토크나이징
def tokenizer(text):
  new_text = clean_text(text)
  new_text = new_text.split()
  return new_text

# %%
#클리닝 및 토크나이징
df['clean_text'] = df['항목명'].apply(clean_text)
df['tokens'] = df['clean_text'].apply(tokenizer)
df.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          유저명  사업자 여부 클라이언트       총 금액        항목명           규격    수량       단가  \
# 0  Lee Jeong       1   김민찬  1500000.0    영문기사 작성          NaN     1  1000000
# 1        이정훈       0  클래스랩  1125000.0  신문사 기사 발행          NaN     5   150000
# 2      siren       1   이운형  8250000.0     김치찌개 팩  구수한맛50g*2ea  1000     2500
#
#       분류  세부분류 clean_text         tokens
# 0   비즈니스  문서작업    영문기사 작성     [영문기사, 작성]
# 1   비즈니스  문서작업  신문사 기사 발행  [신문사, 기사, 발행]
# 2  건강/미용    푸드     김치찌개 팩      [김치찌개, 팩]

# %%
#불용어 지정 
stopwords = ['및', '이', '1종', '겉', '인', '종', '명', '일', '건', '만원']

# %%
#불용어 제외, 영문 번역 토큰 생성
tokens = []

for lines in df['tokens']:    
    lst_tokens = []
    for token in lines:
        #토큰 불용어 아니면 저장
        if token not in stopwords:
          #영문토큰 한글로 통일
          if token == "app":
            lst_tokens.append("앱")
          elif token == "ppt":
            lst_tokens.append("피피티")
          elif token == "PPT":
            lst_tokens.append("피피티")
          elif token == "프레젠테이션":
            lst_tokens.append("피피티")
          elif token == "design":
            lst_tokens.append("디자인")
          elif token == "main":
            lst_tokens.append("메인")
          elif token == "vat":
            lst_tokens.append("수수료")
          else:
            lst_tokens.append(token)

    tokens.append(lst_tokens)
    
df['tokens_no_sw'] = tokens
df.head(3)
# Out:
#          유저명  사업자 여부 클라이언트       총 금액        항목명           규격    수량       단가  \
# 0  Lee Jeong       1   김민찬  1500000.0    영문기사 작성          NaN     1  1000000
# 1        이정훈       0  클래스랩  1125000.0  신문사 기사 발행          NaN     5   150000
# 2      siren       1   이운형  8250000.0     김치찌개 팩  구수한맛50g*2ea  1000     2500
#
#       분류  세부분류 clean_text         tokens   tokens_no_sw
# 0   비즈니스  문서작업    영문기사 작성     [영문기사, 작성]     [영문기사, 작성]
# 1   비즈니스  문서작업  신문사 기사 발행  [신문사, 기사, 발행]  [신문사, 기사, 발행]
# 2  건강/미용    푸드     김치찌개 팩      [김치찌개, 팩]      [김치찌개, 팩]

# %%
#list to string 함수
def list_to_str(lst):
  lst = ' '.join(lst)
  return lst

#clean_text 전처리
df['clean_text'] = df['tokens_no_sw'].apply(list_to_str)

# %% [markdown]
# ##단어추출(konlpy)

# %%
#라이브러리 설치
# !pip install konlpy 
import time
import konlpy
from konlpy.utils import pprint
from konlpy.tag import Hannanum, Kkma, Komoran, Okt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)

# %%
#kkma 단어추출
kkma = Kkma()
df['kkma_noun'] = df['clean_text'].apply(kkma.nouns)
df.head(5)
# Out:
#          유저명  사업자 여부 클라이언트       총 금액        항목명           규격    수량       단가  \
# 0  Lee Jeong       1   김민찬  1500000.0    영문기사 작성          NaN     1  1000000
# 1        이정훈       0  클래스랩  1125000.0  신문사 기사 발행          NaN     5   150000
# 2      siren       1   이운형  8250000.0     김치찌개 팩  구수한맛50g*2ea  1000     2500
# 3      James       1   자운재  8250000.0   블루베리 액기스   얼큰 50g*2ea  1000     3000
# 4        강예호       0    고객   600000.0       문서작업           매절   100     4000
#
#       분류  세부분류 clean_text         tokens   tokens_no_sw           kkma_noun
# 0   비즈니스  문서작업    영문기사 작성     [영문기사, 작성]     [영문기사, 작성]  [영문, 영문기사, 기사, 작성]
# 1   비즈니스  문서작업  신문사 기사 발행  [신문사, 기사, 발행]  [신문사, 기사, 발행]       [신문사, 기사, 발행]
# 2  건강/미용    푸드     김치찌개 팩      [김치찌개, 팩]      [김치찌개, 팩]           [김치찌개, 팩]
# 3  건강/미용    푸드   블루베리 액기스    [블루베리, 액기스]    [블루베리, 액기스]  [블루, 블루베리, 베리, 액기]
# 4   비즈니스  문서작업       문서작업         [문서작업]         [문서작업]      [문서, 문서작업, 작업]

# %%
#OKT 단어추출
Okt = Okt()
df['okt_noun'] = df['clean_text'].apply(Okt.nouns)
df.head(5)
# Out:
#          유저명  사업자 여부 클라이언트       총 금액        항목명           규격    수량       단가  \
# 0  Lee Jeong       1   김민찬  1500000.0    영문기사 작성          NaN     1  1000000
# 1        이정훈       0  클래스랩  1125000.0  신문사 기사 발행          NaN     5   150000
# 2      siren       1   이운형  8250000.0     김치찌개 팩  구수한맛50g*2ea  1000     2500
# 3      James       1   자운재  8250000.0   블루베리 액기스   얼큰 50g*2ea  1000     3000
# 4        강예호       0    고객   600000.0       문서작업           매절   100     4000
#
#       분류  세부분류 clean_text         tokens   tokens_no_sw           kkma_noun  \
# 0   비즈니스  문서작업    영문기사 작성     [영문기사, 작성]     [영문기사, 작성]  [영문, 영문기사, 기사, 작성]
# 1   비즈니스  문서작업  신문사 기사 발행  [신문사, 기사, 발행]  [신문사, 기사, 발행]       [신문사, 기사, 발행]
# 2  건강/미용    푸드     김치찌개 팩      [김치찌개, 팩]      [김치찌개, 팩]           [김치찌개, 팩]
# 3  건강/미용    푸드   블루베리 액기스    [블루베리, 액기스]    [블루베리, 액기스]  [블루, 블루베리, 베리, 액기]
# 4   비즈니스  문서작업       문서작업         [문서작업]         [문서작업]      [문서, 문서작업, 작업]
#
#         okt_noun
# 0   [영문, 기사, 작성]
# 1  [신문사, 기사, 발행]
# 2      [김치찌개, 팩]
# 3    [블루베리, 액기스]
# 4       [문서, 작업]

# %%
#Hannanum 단어추출
Han  = Hannanum()
df['han_noun'] = df['clean_text'].apply(Han.nouns)
df.head(5)
# Out:
#          유저명  사업자 여부 클라이언트       총 금액        항목명           규격    수량       단가  \
# 0  Lee Jeong       1   김민찬  1500000.0    영문기사 작성          NaN     1  1000000
# 1        이정훈       0  클래스랩  1125000.0  신문사 기사 발행          NaN     5   150000
# 2      siren       1   이운형  8250000.0     김치찌개 팩  구수한맛50g*2ea  1000     2500
# 3      James       1   자운재  8250000.0   블루베리 액기스   얼큰 50g*2ea  1000     3000
# 4        강예호       0    고객   600000.0       문서작업           매절   100     4000
#
#       분류  세부분류 clean_text         tokens   tokens_no_sw           kkma_noun  \
# 0   비즈니스  문서작업    영문기사 작성     [영문기사, 작성]     [영문기사, 작성]  [영문, 영문기사, 기사, 작성]
# 1   비즈니스  문서작업  신문사 기사 발행  [신문사, 기사, 발행]  [신문사, 기사, 발행]       [신문사, 기사, 발행]
# 2  건강/미용    푸드     김치찌개 팩      [김치찌개, 팩]      [김치찌개, 팩]           [김치찌개, 팩]
# 3  건강/미용    푸드   블루베리 액기스    [블루베리, 액기스]    [블루베리, 액기스]  [블루, 블루베리, 베리, 액기]
# 4   비즈니스  문서작업       문서작업         [문서작업]         [문서작업]      [문서, 문서작업, 작업]
#
#         okt_noun       han_noun
# 0   [영문, 기사, 작성]     [영문기사, 작성]
# 1  [신문사, 기사, 발행]  [신문사, 기사, 발행]
# 2      [김치찌개, 팩]      [김치찌개, 팩]
# 3    [블루베리, 액기스]    [블루베리, 액기스]
# 4       [문서, 작업]         [문서작업]

# %%
#komoran 단어추출
Kom  = Komoran()
df['kom_noun'] = df['clean_text'].apply(Kom.nouns)
df.head(5)
# Out:
#          유저명  사업자 여부 클라이언트       총 금액        항목명           규격    수량       단가  \
# 0  Lee Jeong       1   김민찬  1500000.0    영문기사 작성          NaN     1  1000000
# 1        이정훈       0  클래스랩  1125000.0  신문사 기사 발행          NaN     5   150000
# 2      siren       1   이운형  8250000.0     김치찌개 팩  구수한맛50g*2ea  1000     2500
# 3      James       1   자운재  8250000.0   블루베리 액기스   얼큰 50g*2ea  1000     3000
# 4        강예호       0    고객   600000.0       문서작업           매절   100     4000
#
#       분류  세부분류 clean_text         tokens   tokens_no_sw           kkma_noun  \
# 0   비즈니스  문서작업    영문기사 작성     [영문기사, 작성]     [영문기사, 작성]  [영문, 영문기사, 기사, 작성]
# 1   비즈니스  문서작업  신문사 기사 발행  [신문사, 기사, 발행]  [신문사, 기사, 발행]       [신문사, 기사, 발행]
# 2  건강/미용    푸드     김치찌개 팩      [김치찌개, 팩]      [김치찌개, 팩]           [김치찌개, 팩]
# 3  건강/미용    푸드   블루베리 액기스    [블루베리, 액기스]    [블루베리, 액기스]  [블루, 블루베리, 베리, 액기]
# 4   비즈니스  문서작업       문서작업         [문서작업]         [문서작업]      [문서, 문서작업, 작업]
#
#         okt_noun       han_noun       kom_noun
# 0   [영문, 기사, 작성]     [영문기사, 작성]   [영문, 기사, 작성]
# 1  [신문사, 기사, 발행]  [신문사, 기사, 발행]  [신문사, 기사, 발행]
# 2      [김치찌개, 팩]      [김치찌개, 팩]      [김치찌개, 팩]
# 3    [블루베리, 액기스]    [블루베리, 액기스]         [블루베리]
# 4       [문서, 작업]         [문서작업]       [문서, 작업]

# %% [markdown]
# ## 맞춤법 수정

# %% [markdown]
# ###라이브러리

# %%
#라이브러리 설치 및 import
#!pip install git+https://github.com/haven-jeon/PyKoSpacing.git
#!pip install git+https://github.com/ssut/py-hanspell.git
from pykospacing import Spacing
from hanspell import spell_checker
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ###Hanspell

# %%
#hanspell
def han_spell_check(x):
  x = x.strip() # 113-114 \t
  res = spell_checker.check(x)
  result = res.checked
  return result

# %%
df['clen_text_hansp'] = df['clean_text'].apply(han_spell_check)
df
# Out:
#            유저명  사업자 여부  클라이언트       총 금액          항목명           규격    수량  \
# 0    Lee Jeong       1    김민찬  1500000.0      영문기사 작성          NaN     1
# 1          이정훈       0   클래스랩  1125000.0    신문사 기사 발행          NaN     5
# 2        siren       1    이운형  8250000.0       김치찌개 팩  구수한맛50g*2ea  1000
# 3        James       1    자운재  8250000.0     블루베리 액기스   얼큰 50g*2ea  1000
# 4          강예호       0     고객   600000.0         문서작업           매절   100
# ..         ...     ...    ...        ...          ...          ...   ...
# 396        허준오       1  미디어세상  9000000.0  양천구청 캐릭터 제작      타이틀(3D)     1
# 397        허준오       1  미디어세상  4200000.0    미디어 예술상회         로고 제작     1
# 398        허준오       1  미디어세상  4200000.0    미디어 예술상회       타이틀/15초     1
# 399        허준오       0    오유정  4500000.0   MBC 방송 타이틀       FHD15초     1
# 400        황수현       1    IOU  4275000.0          관리기    AMC-880SM     1
#
#           단가       분류     세부분류   clean_text           tokens     tokens_no_sw  \
# 0    1000000     비즈니스     문서작업      영문기사 작성       [영문기사, 작성]       [영문기사, 작성]
# 1     150000     비즈니스     문서작업    신문사 기사 발행    [신문사, 기사, 발행]    [신문사, 기사, 발행]
# 2       2500    건강/미용       푸드       김치찌개 팩        [김치찌개, 팩]        [김치찌개, 팩]
# 3       3000    건강/미용       푸드     블루베리 액기스      [블루베리, 액기스]      [블루베리, 액기스]
# 4       4000     비즈니스     문서작업         문서작업           [문서작업]           [문서작업]
# ..       ...      ...      ...          ...              ...              ...
# 396  6000000  상업용 디자인  상업용 디자인  양천구청 캐릭터 제작  [양천구청, 캐릭터, 제작]  [양천구청, 캐릭터, 제작]
# 397   300000  상업용 디자인  상업용 디자인     미디어 예술상회      [미디어, 예술상회]      [미디어, 예술상회]
# 398  2500000      미디어      미디어     미디어 예술상회      [미디어, 예술상회]      [미디어, 예술상회]
# 399  3000000      미디어      미디어   mbc 방송 타이틀   [mbc, 방송, 타이틀]   [mbc, 방송, 타이틀]
# 400  2850000    기기/기술  전자/소형설비          관리기            [관리기]            [관리기]
#
#                    kkma_noun         okt_noun         han_noun  \
# 0         [영문, 영문기사, 기사, 작성]     [영문, 기사, 작성]       [영문기사, 작성]
# 1              [신문사, 기사, 발행]    [신문사, 기사, 발행]    [신문사, 기사, 발행]
# 2                  [김치찌개, 팩]        [김치찌개, 팩]        [김치찌개, 팩]
# 3         [블루, 블루베리, 베리, 액기]      [블루베리, 액기스]      [블루베리, 액기스]
# 4             [문서, 문서작업, 작업]         [문서, 작업]           [문서작업]
# ..                       ...              ...              ...
# 396  [양천, 양천구청, 구청, 캐릭터, 제작]  [양천구청, 캐릭터, 제작]  [양천구청, 캐릭터, 제작]
# 397      [미디어, 예술, 예술상회, 상회]    [미디어, 예술, 상회]      [미디어, 예술상회]
# 398      [미디어, 예술, 예술상회, 상회]    [미디어, 예술, 상회]      [미디어, 예술상회]
# 399                [방송, 타이틀]        [방송, 타이틀]        [방송, 타이틀]
# 400                    [관리기]          [관리, 기]            [관리기]
#
#               kom_noun clen_text_hansp
# 0         [영문, 기사, 작성]        영문 기사 작성
# 1        [신문사, 기사, 발행]       신문사 기사 발행
# 2            [김치찌개, 팩]          김치찌개 팩
# 3               [블루베리]         블루베리 진액
# 4             [문서, 작업]            문서작업
# ..                 ...             ...
# 396  [양천, 구청, 캐릭터, 제작]     양천구청 캐릭터 제작
# 397      [미디어, 예술, 상회]        미디어 예술상회
# 398      [미디어, 예술, 상회]        미디어 예술상회
# 399          [방송, 타이틀]      mbc 방송 타이틀
# 400               [관리]             관리기
#
# [332 rows x 18 columns]

# %% [markdown]
# ###Pykospacing

# %%
#pykospacing
spacing = Spacing()

# %%
import os
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
#pykospacing 적용
df['clean_text_pyko'] = df['clen_text_hansp'].apply(spacing)
df
# Out:
#            유저명  사업자 여부  클라이언트       총 금액          항목명           규격    수량  \
# 0    Lee Jeong       1    김민찬  1500000.0      영문기사 작성          NaN     1
# 1          이정훈       0   클래스랩  1125000.0    신문사 기사 발행          NaN     5
# 2        siren       1    이운형  8250000.0       김치찌개 팩  구수한맛50g*2ea  1000
# 3        James       1    자운재  8250000.0     블루베리 액기스   얼큰 50g*2ea  1000
# 4          강예호       0     고객   600000.0         문서작업           매절   100
# ..         ...     ...    ...        ...          ...          ...   ...
# 396        허준오       1  미디어세상  9000000.0  양천구청 캐릭터 제작      타이틀(3D)     1
# 397        허준오       1  미디어세상  4200000.0    미디어 예술상회         로고 제작     1
# 398        허준오       1  미디어세상  4200000.0    미디어 예술상회       타이틀/15초     1
# 399        허준오       0    오유정  4500000.0   MBC 방송 타이틀       FHD15초     1
# 400        황수현       1    IOU  4275000.0          관리기    AMC-880SM     1
#
#           단가       분류     세부분류   clean_text           tokens     tokens_no_sw  \
# 0    1000000     비즈니스     문서작업      영문기사 작성       [영문기사, 작성]       [영문기사, 작성]
# 1     150000     비즈니스     문서작업    신문사 기사 발행    [신문사, 기사, 발행]    [신문사, 기사, 발행]
# 2       2500    건강/미용       푸드       김치찌개 팩        [김치찌개, 팩]        [김치찌개, 팩]
# 3       3000    건강/미용       푸드     블루베리 액기스      [블루베리, 액기스]      [블루베리, 액기스]
# 4       4000     비즈니스     문서작업         문서작업           [문서작업]           [문서작업]
# ..       ...      ...      ...          ...              ...              ...
# 396  6000000  상업용 디자인  상업용 디자인  양천구청 캐릭터 제작  [양천구청, 캐릭터, 제작]  [양천구청, 캐릭터, 제작]
# 397   300000  상업용 디자인  상업용 디자인     미디어 예술상회      [미디어, 예술상회]      [미디어, 예술상회]
# 398  2500000      미디어      미디어     미디어 예술상회      [미디어, 예술상회]      [미디어, 예술상회]
# 399  3000000      미디어      미디어   mbc 방송 타이틀   [mbc, 방송, 타이틀]   [mbc, 방송, 타이틀]
# 400  2850000    기기/기술  전자/소형설비          관리기            [관리기]            [관리기]
#
#                    kkma_noun         okt_noun         han_noun  \
# 0         [영문, 영문기사, 기사, 작성]     [영문, 기사, 작성]       [영문기사, 작성]
# 1              [신문사, 기사, 발행]    [신문사, 기사, 발행]    [신문사, 기사, 발행]
# 2                  [김치찌개, 팩]        [김치찌개, 팩]        [김치찌개, 팩]
# 3         [블루, 블루베리, 베리, 액기]      [블루베리, 액기스]      [블루베리, 액기스]
# 4             [문서, 문서작업, 작업]         [문서, 작업]           [문서작업]
# ..                       ...              ...              ...
# 396  [양천, 양천구청, 구청, 캐릭터, 제작]  [양천구청, 캐릭터, 제작]  [양천구청, 캐릭터, 제작]
# 397      [미디어, 예술, 예술상회, 상회]    [미디어, 예술, 상회]      [미디어, 예술상회]
# 398      [미디어, 예술, 예술상회, 상회]    [미디어, 예술, 상회]      [미디어, 예술상회]
# 399                [방송, 타이틀]        [방송, 타이틀]        [방송, 타이틀]
# 400                    [관리기]          [관리, 기]            [관리기]
#
#               kom_noun clen_text_hansp clean_text_pyko
# 0         [영문, 기사, 작성]        영문 기사 작성        영문 기사 작성
# 1        [신문사, 기사, 발행]       신문사 기사 발행       신문사 기사 발행
# 2            [김치찌개, 팩]          김치찌개 팩          김치찌개 팩
# 3               [블루베리]         블루베리 진액         블루베리 진액
# 4             [문서, 작업]            문서작업           문서 작업
# ..                 ...             ...             ...
# 396  [양천, 구청, 캐릭터, 제작]     양천구청 캐릭터 제작     양천구청 캐릭터 제작
# 397      [미디어, 예술, 상회]        미디어 예술상회        미디어 예술상회
# 398      [미디어, 예술, 상회]        미디어 예술상회        미디어 예술상회
# 399          [방송, 타이틀]      mbc 방송 타이틀      mbc 방송 타이틀
# 400               [관리]             관리기             관리기
#
# [332 rows x 19 columns]

# %% [markdown]
# ## 불용어 처리(심화)

# %%
#불용어 지정 
stopwords = ['및', '이', '1종', '겉', '인', '종', '명', '일', '건', '비', '배', '티', '싱', '수', '리', '싱', '포', '피', '장', '레', '테', '션', '거', '지', '만원']

# %%
#불용어 제거
tokens = []
df2 = df.iloc[:, np.r_[12, 13:17]]
cols = df2.columns
cols
# Out:
# Index(['tokens_no_sw', 'kkma_noun', 'okt_noun', 'han_noun', 'kom_noun'], dtype='object')

# %%
#불용어 제거
for col in cols:
  for lines in df[col]:
    lst_tokens = []
    for token in lines:
      # 토큰이 불용어가 아니면 저장
      if token in stopwords:
        lines.remove(token)

df[cols]
# Out:
#         tokens_no_sw                kkma_noun         okt_noun  \
# 0         [영문기사, 작성]       [영문, 영문기사, 기사, 작성]     [영문, 기사, 작성]
# 1      [신문사, 기사, 발행]            [신문사, 기사, 발행]    [신문사, 기사, 발행]
# 2          [김치찌개, 팩]                [김치찌개, 팩]        [김치찌개, 팩]
# 3        [블루베리, 액기스]       [블루, 블루베리, 베리, 액기]      [블루베리, 액기스]
# 4             [문서작업]           [문서, 문서작업, 작업]         [문서, 작업]
# ..               ...                      ...              ...
# 396  [양천구청, 캐릭터, 제작]  [양천, 양천구청, 구청, 캐릭터, 제작]  [양천구청, 캐릭터, 제작]
# 397      [미디어, 예술상회]      [미디어, 예술, 예술상회, 상회]    [미디어, 예술, 상회]
# 398      [미디어, 예술상회]      [미디어, 예술, 예술상회, 상회]    [미디어, 예술, 상회]
# 399   [mbc, 방송, 타이틀]                [방송, 타이틀]        [방송, 타이틀]
# 400            [관리기]                    [관리기]          [관리, 기]
#
#             han_noun           kom_noun
# 0         [영문기사, 작성]       [영문, 기사, 작성]
# 1      [신문사, 기사, 발행]      [신문사, 기사, 발행]
# 2          [김치찌개, 팩]          [김치찌개, 팩]
# 3        [블루베리, 액기스]             [블루베리]
# 4             [문서작업]           [문서, 작업]
# ..               ...                ...
# 396  [양천구청, 캐릭터, 제작]  [양천, 구청, 캐릭터, 제작]
# 397      [미디어, 예술상회]      [미디어, 예술, 상회]
# 398      [미디어, 예술상회]      [미디어, 예술, 상회]
# 399        [방송, 타이틀]          [방송, 타이틀]
# 400            [관리기]               [관리]
#
# [332 rows x 5 columns]

# %% [markdown]
# # 데이터 분석

# %% [markdown]
# ## WORD COUNT

# %%
#WORD COUNTER
from collections import Counter
word_counts = Counter()

#불용어 제거 후 top10 words
df['tokens_no_sw'].apply(lambda x: word_counts.update(x))
word_counts.most_common(30)
# Out:
# [('디자인', 37),
#  ('제작', 16),
#  ('웹싸이트', 15),
#  ('피피티', 13),
#  ('로고', 10),
#  ('메이크업', 8),
#  ('퍼블리싱', 8),
#  ('개발', 7),
#  ('홈페이지', 7),
#  ('텀블러', 7),
#  ('헤어', 7),
#  ('메인페이지', 7),
#  ('앱', 7),
#  ('실크', 7),
#  ('포스터', 6),
#  ('배너', 6),
#  ('재질', 6),
#  ('시공', 5),
#  ('작업', 5),
#  ('인건비', 5),
#  ('포토앨범용', 5),
#  ('서버', 5),
#  ('수정', 5),
#  ('발행', 4),
#  ('설치', 4),
#  ('호스팅', 4),
#  ('웹디자인', 4),
#  ('부가세', 4),
#  ('라벨', 4),
#  ('도배', 4)]

# %%
#토큰 수, 빈도 순위, 존재 문서 수, 비율 등 정보

def word_count(docs):

    # 전체 코퍼스에서 단어 빈도 카운트
    word_counts = Counter()

    # 단어가 존재하는 문서의 빈도 카운트, 단어가 한 번 이상 존재하면 +1
    word_in_docs = Counter()

    # 전체 문서의 갯수
    total_docs = len(docs)

    for doc in docs:
        word_counts.update(doc)
        word_in_docs.update(set(doc))

    temp = zip(word_counts.keys(), word_counts.values())

    wc = pd.DataFrame(temp, columns = ['word', 'count'])

    # 단어의 순위
    # method='first': 같은 값의 경우 먼저나온 요소를 우선
    wc['rank'] = wc['count'].rank(method='first', ascending=False)
    total = wc['count'].sum()

    # 코퍼스 내 단어의 비율
    wc['percent'] = wc['count'].apply(lambda x: x / total)

    wc = wc.sort_values(by='rank')

    # 누적 비율
    # cumsum() : cumulative sum
    wc['cul_percent'] = wc['percent'].cumsum()

    temp2 = zip(word_in_docs.keys(), word_in_docs.values())
    ac = pd.DataFrame(temp2, columns=['word', 'word_in_docs'])
    wc = ac.merge(wc, on='word')
    
    # 전체 문서 중 존재하는 비율
    wc['word_in_docs_percent'] = wc['word_in_docs'].apply(lambda x: x / total_docs)

    return wc.sort_values(by='rank')

# %%
wc = word_count(df['tokens_no_sw'])
wc.head(10)
# Out:
#      word  word_in_docs  count  rank   percent  cul_percent  \
# 53    디자인            37     37   1.0  0.056662     0.056662
# 11     제작            16     16   2.0  0.024502     0.081164
# 43   웹싸이트            15     15   3.0  0.022971     0.104135
# 52    피피티            13     13   4.0  0.019908     0.124043
# 13     로고            10     10   5.0  0.015314     0.139357
# 148  메이크업             8      8   6.0  0.012251     0.151608
# 190  퍼블리싱             8      8   7.0  0.012251     0.163859
# 18     개발             7      7   8.0  0.010720     0.174579
# 47   홈페이지             7      7   9.0  0.010720     0.185299
# 87    텀블러             7      7  10.0  0.010720     0.196018
#
#      word_in_docs_percent
# 53               0.111446
# 11               0.048193
# 43               0.045181
# 52               0.039157
# 13               0.030120
# 148              0.024096
# 190              0.024096
# 18               0.021084
# 47               0.021084
# 87               0.021084

# %%
# !pip install squarify
import squarify
import matplotlib.pyplot as plt
import matplotlib as mpl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: squarify in /usr/local/lib/python3.7/dist-packages (0.4.3)

# %%
# 한글 폰트 사용을 위해서 세팅
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.rc('font', family='NanumBarunGothic')
mpl.rc('font', family='NanumBarunGothic')
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
#!rm ~/.cache/matplotlib -rf

# %%
#top20 단어
wc = word_count(df['tokens_no_sw'])
wc.head(20)
# Out:
#       word  word_in_docs  count  rank   percent  cul_percent  \
# 53     디자인            37     37   1.0  0.056662     0.056662
# 11      제작            16     16   2.0  0.024502     0.081164
# 43    웹싸이트            15     15   3.0  0.022971     0.104135
# 52     피피티            13     13   4.0  0.019908     0.124043
# 13      로고            10     10   5.0  0.015314     0.139357
# 148   메이크업             8      8   6.0  0.012251     0.151608
# 190   퍼블리싱             8      8   7.0  0.012251     0.163859
# 18      개발             7      7   8.0  0.010720     0.174579
# 47    홈페이지             7      7   9.0  0.010720     0.185299
# 87     텀블러             7      7  10.0  0.010720     0.196018
# 147     헤어             7      7  11.0  0.010720     0.206738
# 184  메인페이지             7      7  12.0  0.010720     0.217458
# 185      앱             7      7  13.0  0.010720     0.228178
# 301     실크             7      7  14.0  0.010720     0.238897
# 12     포스터             6      6  15.0  0.009188     0.248086
# 128     배너             6      6  16.0  0.009188     0.257274
# 300     재질             6      6  17.0  0.009188     0.266462
# 34      시공             5      5  18.0  0.007657     0.274119
# 126     작업             5      5  19.0  0.007657     0.281776
# 135    인건비             5      5  20.0  0.007657     0.289433
#
#      word_in_docs_percent
# 53               0.111446
# 11               0.048193
# 43               0.045181
# 52               0.039157
# 13               0.030120
# 148              0.024096
# 190              0.024096
# 18               0.021084
# 47               0.021084
# 87               0.021084
# 147              0.021084
# 184              0.021084
# 185              0.021084
# 301              0.021084
# 12               0.018072
# 128              0.018072
# 300              0.018072
# 34               0.015060
# 126              0.015060
# 135              0.015060

# %%
#스쿼리파이 top10 토큰 시각화 -> 한글깨짐 오류 -> 런타임 재시작으로 해결 
wc_top10 = wc[wc['rank'] <= 20]
squarify.plot(sizes=wc_top10['percent'], label=wc_top10['word'], alpha=0.6)
plt.rc('font', family='NanumBarunGothic')
plt.axis('off')
plt.show()

# %%
#top20 단어
wc = word_count(df['tokens_no_sw'])
wc.head(20)
# Out:
#       word  word_in_docs  count  rank   percent  cul_percent  \
# 53     디자인            37     37   1.0  0.056662     0.056662
# 11      제작            16     16   2.0  0.024502     0.081164
# 43    웹싸이트            15     15   3.0  0.022971     0.104135
# 52     피피티            13     13   4.0  0.019908     0.124043
# 13      로고            10     10   5.0  0.015314     0.139357
# 148   메이크업             8      8   6.0  0.012251     0.151608
# 190   퍼블리싱             8      8   7.0  0.012251     0.163859
# 18      개발             7      7   8.0  0.010720     0.174579
# 47    홈페이지             7      7   9.0  0.010720     0.185299
# 87     텀블러             7      7  10.0  0.010720     0.196018
# 147     헤어             7      7  11.0  0.010720     0.206738
# 184  메인페이지             7      7  12.0  0.010720     0.217458
# 185      앱             7      7  13.0  0.010720     0.228178
# 301     실크             7      7  14.0  0.010720     0.238897
# 12     포스터             6      6  15.0  0.009188     0.248086
# 128     배너             6      6  16.0  0.009188     0.257274
# 300     재질             6      6  17.0  0.009188     0.266462
# 34      시공             5      5  18.0  0.007657     0.274119
# 126     작업             5      5  19.0  0.007657     0.281776
# 135    인건비             5      5  20.0  0.007657     0.289433
#
#      word_in_docs_percent
# 53               0.111446
# 11               0.048193
# 43               0.045181
# 52               0.039157
# 13               0.030120
# 148              0.024096
# 190              0.024096
# 18               0.021084
# 47               0.021084
# 87               0.021084
# 147              0.021084
# 184              0.021084
# 185              0.021084
# 301              0.021084
# 12               0.018072
# 128              0.018072
# 300              0.018072
# 34               0.015060
# 126              0.015060
# 135              0.015060

# %%
#불용어 제거 후 성능
wc = word_count(df['okt_noun'])
wc.head(20)
# Out:
#      word  word_in_docs  count  rank   percent  cul_percent  \
# 61    디자인            47     47   1.0  0.059873     0.059873
# 13     제작            19     19   2.0  0.024204     0.084076
# 50      웹            16     16   3.0  0.020382     0.104459
# 49    싸이트            15     15   4.0  0.019108     0.123567
# 125   페이지            15     15   5.0  0.019108     0.142675
# 15     로고            14     14   6.0  0.017834     0.160510
# 60    피피티            13     13   7.0  0.016561     0.177070
# 10     작업            11     11   8.0  0.014013     0.191083
# 191    메인            10     10   9.0  0.012739     0.203822
# 21     개발             9      9  10.0  0.011465     0.215287
# 71     홍보             9      9  11.0  0.011465     0.226752
# 70      용             9      9  12.0  0.011465     0.238217
# 139   인건비             8      8  13.0  0.010191     0.248408
# 154  메이크업             8      8  14.0  0.010191     0.258599
# 194  퍼블리싱             8      8  15.0  0.010191     0.268790
# 55   홈페이지             7      7  16.0  0.008917     0.277707
# 90    텀블러             7      7  17.0  0.008917     0.286624
# 130    배너             7      7  18.0  0.008917     0.295541
# 153    헤어             7      7  19.0  0.008917     0.304459
# 192     앱             7      7  20.0  0.008917     0.313376
#
#      word_in_docs_percent
# 61               0.141566
# 13               0.057229
# 50               0.048193
# 49               0.045181
# 125              0.045181
# 15               0.042169
# 60               0.039157
# 10               0.033133
# 191              0.030120
# 21               0.027108
# 71               0.027108
# 70               0.027108
# 139              0.024096
# 154              0.024096
# 194              0.024096
# 55               0.021084
# 90               0.021084
# 130              0.021084
# 153              0.021084
# 192              0.021084

# %%
df.iloc[:, np.r_[4, 12, 13:17]].head(50)
# Out:
#             항목명     tokens_no_sw            kkma_noun         okt_noun  \
# 0       영문기사 작성       [영문기사, 작성]   [영문, 영문기사, 기사, 작성]     [영문, 기사, 작성]
# 1     신문사 기사 발행    [신문사, 기사, 발행]        [신문사, 기사, 발행]    [신문사, 기사, 발행]
# 2        김치찌개 팩        [김치찌개, 팩]            [김치찌개, 팩]        [김치찌개, 팩]
# 3      블루베리 액기스      [블루베리, 액기스]   [블루, 블루베리, 베리, 액기]      [블루베리, 액기스]
# 4          문서작업           [문서작업]       [문서, 문서작업, 작업]         [문서, 작업]
# 5         녹음시스템          [녹음시스템]     [녹음, 녹음시스템, 시스템]        [녹음, 시스템]
# 6        포스터 제작        [포스터, 제작]            [포스터, 제작]        [포스터, 제작]
# 7         로고 제작         [로고, 제작]             [로고, 제작]         [로고, 제작]
# 8          인테리어           [인테리어]               [인테리어]           [인테리어]
# 9          인테리어           [인테리어]               [인테리어]           [인테리어]
# 10      프린터기 렌탈       [프린터기, 렌탈]    [프린터, 프린터기, 기, 렌]       [프린터기, 렌탈]
# 11      예약어플 개발       [예약어플, 개발]   [예약어, 예약어플, 플, 개발]     [예약, 어플, 개발]
# 12     프로그래밍 강의      [프로그래밍, 강의]          [프로그래밍, 강의]      [프로그래밍, 강의]
# 13     프로그래밍 강의      [프로그래밍, 강의]          [프로그래밍, 강의]      [프로그래밍, 강의]
# 14    도어 유리창 코팅    [도어, 유리창, 코팅]        [도어, 유리창, 코팅]    [도어, 유리창, 코팅]
# 15        휀더 코팅         [휀더, 코팅]              [휀, 코팅]         [휀더, 코팅]
# 16        범퍼 코팅         [범퍼, 코팅]             [범퍼, 코팅]         [범퍼, 코팅]
# 18    세면대 수전 설치    [세면대, 수전, 설치]        [세면대, 수전, 설치]    [세면대, 수전, 설치]
# 19       변기통 설치        [변기통, 설치]            [변기통, 설치]      [변기, 통, 설치]
# 20       콘센트 제작        [콘센트, 제작]            [콘센트, 제작]        [콘센트, 제작]
# 21      웹툰 프로젝트       [웹툰, 프로젝트]     [웹, 웹툰, 툰, 프로젝트]       [웹툰, 프로젝트]
# 22      암막커텐 시공       [암막커텐, 시공]           [암, 터, 시공]      [막, 커텐, 시공]
# 23  비즈니스 경영 컨설팅  [비즈니스, 경영, 컨설팅]      [비즈니스, 경영, 컨설팅]  [비즈니스, 경영, 컨설팅]
# 26        찰떡 세트         [찰떡, 세트]             [찰떡, 세트]         [찰떡, 세트]
# 27         콘브레드           [콘브레드]       [콘, 콘브레드, 브레드]         [콘, 브레드]
# 28         샌드위치           [샌드위치]               [샌드위치]           [샌드위치]
# 45      웹싸이트 보안       [웹싸이트, 보안]   [웹, 웹싸이트, 싸이트, 보안]     [웹, 싸이트, 보안]
# 46         유지보수           [유지보수]       [유지, 유지보수, 보수]         [유지, 보수]
# 47     웹싸이트 호스팅      [웹싸이트, 호스팅]  [웹, 웹싸이트, 싸이트, 호스팅]    [웹, 싸이트, 호스팅]
# 48      홈페이지 구축       [홈페이지, 구축]           [홈페이지, 구축]       [홈페이지, 구축]
# 49     웹싸이트 호스팅      [웹싸이트, 호스팅]  [웹, 웹싸이트, 싸이트, 호스팅]    [웹, 싸이트, 호스팅]
# 50         유지보수           [유지보수]       [유지, 유지보수, 보수]         [유지, 보수]
# 51       인증서 발행        [인증서, 발행]            [인증서, 발행]        [인증서, 발행]
# 52      홈페이지 구축       [홈페이지, 구축]           [홈페이지, 구축]       [홈페이지, 구축]
# 53           점심             [점심]                 [점심]             [점심]
# 54         퀵서비스           [퀵서비스]                [서비스]           [퀵서비스]
# 55         퀵서비스           [퀵서비스]                [서비스]           [퀵서비스]
# 56           점심             [점심]                 [점심]             [점심]
# 57         웹디자인           [웹디자인]       [웹, 웹디자인, 디자인]           [웹디자인]
# 58         유지보수           [유지보수]       [유지, 유지보수, 보수]         [유지, 보수]
# 59      홈페이지 제작       [홈페이지, 제작]           [홈페이지, 제작]       [홈페이지, 제작]
# 60       인증서 발행        [인증서, 발행]            [인증서, 발행]        [인증서, 발행]
# 61      웹싸이트 발행       [웹싸이트, 발행]   [웹, 웹싸이트, 싸이트, 발행]     [웹, 싸이트, 발행]
# 62         웹디자인           [웹디자인]       [웹, 웹디자인, 디자인]           [웹디자인]
# 63         웹디자인           [웹디자인]       [웹, 웹디자인, 디자인]           [웹디자인]
# 64      ppt 디자인       [피피티, 디자인]           [피피티, 디자인]       [피피티, 디자인]
# 65      ppt 디자인       [피피티, 디자인]           [피피티, 디자인]       [피피티, 디자인]
# 66       포스터 제작        [포스터, 제작]            [포스터, 제작]        [포스터, 제작]
# 67          부가세            [부가세]                [부가세]            [부가세]
# 68  피피티 제작 - 은행    [피피티, 제작, 은행]        [피피티, 제작, 은행]    [피피티, 제작, 은행]
#
#            han_noun         kom_noun
# 0        [영문기사, 작성]     [영문, 기사, 작성]
# 1     [신문사, 기사, 발행]    [신문사, 기사, 발행]
# 2         [김치찌개, 팩]        [김치찌개, 팩]
# 3       [블루베리, 액기스]           [블루베리]
# 4            [문서작업]         [문서, 작업]
# 5           [녹음시스템]        [녹음, 시스템]
# 6         [포스터, 제작]        [포스터, 제작]
# 7          [로고, 제작]         [로고, 제작]
# 8            [인테리어]           [인테리어]
# 9            [인테리어]           [인테리어]
# 10        [프린터, 렌탈]            [프린터]
# 11       [예약어플, 개발]         [예약, 개발]
# 12      [프로그래밍, 강의]      [프로그래밍, 강의]
# 13      [프로그래밍, 강의]      [프로그래밍, 강의]
# 14     [도, 유리창, 코팅]    [도어, 유리창, 코팅]
# 15         [휀더, 코팅]          [훼, 코팅]
# 16         [범퍼, 코팅]         [범퍼, 코팅]
# 18    [세면대, 수전, 설치]     [세면대, 전, 설치]
# 19        [변기통, 설치]        [변기통, 설치]
# 20        [콘센트, 제작]        [콘센트, 제작]
# 21       [웹툰, 프로젝트]       [웹툰, 프로젝트]
# 22       [암막커텐, 시공]   [암, 막, 커텐, 시공]
# 23  [비즈니스, 경영, 컨설팅]  [비즈니스, 경영, 컨설팅]
# 26         [찰떡, 세트]         [찰떡, 세트]
# 27           [콘브레드]           [콘브레드]
# 28           [샌드위치]           [샌드위치]
# 45       [웹싸이트, 보안]      [웹, 싸이, 보안]
# 46           [유지보수]         [유지, 보수]
# 47      [웹싸이트, 호스팅]     [웹, 싸이, 호스팅]
# 48       [홈페이지, 구축]       [홈페이지, 구축]
# 49      [웹싸이트, 호스팅]     [웹, 싸이, 호스팅]
# 50           [유지보수]         [유지, 보수]
# 51         [인증, 발행]         [인증, 발행]
# 52       [홈페이지, 구축]       [홈페이지, 구축]
# 53             [점심]             [점심]
# 54           [퀵서비스]           [퀵서비스]
# 55           [퀵서비스]           [퀵서비스]
# 56             [점심]             [점심]
# 57            [웹디자]         [웹, 디자인]
# 58           [유지보수]         [유지, 보수]
# 59       [홈페이지, 제작]       [홈페이지, 제작]
# 60         [인증, 발행]         [인증, 발행]
# 61       [웹싸이트, 발행]      [웹, 싸이, 발행]
# 62            [웹디자]         [웹, 디자인]
# 63            [웹디자]         [웹, 디자인]
# 64       [피피티, 디자인]         [티, 디자인]
# 65       [피피티, 디자인]         [티, 디자인]
# 66        [포스터, 제작]        [포스터, 제작]
# 67            [부가세]            [부가세]
# 68    [피피티, 제작, 은행]      [티, 제작, 은행]

# %%
cols
# Out:
# Index(['tokens_no_sw', 'kkma_noun', 'okt_noun', 'han_noun', 'kom_noun'], dtype='object')

# %%
wc_tk = word_count(df['tokens_no_sw'])
wc_tk = wc_tk.rename(columns={"word": "word_tk"})
wc_tk.reset_index(drop=True, inplace=True)

# %%
wc_kkma = word_count(df['kkma_noun'])
wc_kkma = wc_kkma.rename(columns={"word": "word_kkma"})
wc_kkma.reset_index(drop=True, inplace=True)

# %%
wc_okt = word_count(df['okt_noun'])
wc_okt = wc_okt.rename(columns={"word": "word_okt"})
wc_okt.reset_index(drop=True, inplace=True)

# %%
wc_han = word_count(df['han_noun'])
wc_han = wc_han.rename(columns={"word": "word_han"})
wc_han.reset_index(drop=True, inplace=True)

# %%
wc_kom = word_count(df['kom_noun'])
wc_kom = wc_kom.rename(columns={"word": "word_kom"})
wc_kom.reset_index(drop=True, inplace=True)

# %%
df_wc = pd.concat([wc_tk['word_tk'], wc_kkma['word_kkma'], wc_okt['word_okt'], wc_han['word_han'], wc_kom['word_kom']], axis=1)
df_wc.head(50)
# Out:
#    word_tk word_kkma word_okt word_han word_kom
# 0      디자인       디자인      디자인      디자인      디자인
# 1       제작         웹       제작       제작        웹
# 2     웹싸이트        제작        웹     웹싸이트       제작
# 3      피피티      웹싸이트      싸이트      피피티       싸이
# 4       로고       싸이트      페이지       로고       로고
# 5     메이크업       페이지       로고     메이크업      페이지
# 6     퍼블리싱        로고      피피티     퍼블리싱        티
# 7       개발       피피티       작업       개발       작업
# 8     홈페이지        작업       메인     홈페이지       메인
# 9      텀블러        메인       개발      텀블러       개발
# 10      헤어        개발       홍보    메인페이지      인건비
# 11   메인페이지       인건비        용        앱     메이크업
# 12       앱      메이크업      인건비       실크     퍼블리싱
# 13      실크        리싱     메이크업      포스터     홈페이지
# 14     포스터      홈페이지     퍼블리싱       배너       영상
# 15      배너        영상     홈페이지       시공      텀블러
# 16      재질       텀블러      텀블러       작업       헤어
# 17      시공        헤어       배너      인건비       실크
# 18      작업     메인페이지       헤어    포토앨범용       재질
# 19     인건비         앱        앱       서버      포스터
# 20   포토앨범용        실크       실크       수정       시공
# 21      서버        재질       재질       발행      모바일
# 22      수정       포스터      포스터       설치       메뉴
# 23      발행        설치       설치      호스팅      미디어
# 24      설치        시공       시공      웹디자       설치
# 25     호스팅         너       영상      부가세      부가세
# 26    웹디자인        수제      모바일       라벨       홍보
# 27     부가세       모바일      미디어       도배       포토
# 28      라벨       미디어      부가세       모바       앨범
# 29      도배       부가세        기      홍보지       수정
# 30     모바일        홍보       포토     디자인비       택배
# 31     홍보지        포토       앨범     수제홍차       발행
# 32    디자인비      포토앨범       서버     선물상자      호스팅
# 33    수제홍차        앨범       수정      스티커       파일
# 34    선물상자        서버       택배      미디어       구입
# 35      내지        수정       발행    안압측정기       라벨
# 36     스티커        택배      호스팅       코팅       도배
# 37     미디어       택배비     웹디자인     유지보수       서버
# 38   안압측정기        발행       파일       구축        홍
# 39      코팅       호스팅       구입       엔터       보지
# 40    유지보수      웹디자인       라벨      이미지       수제
# 41      구축        파일       도배       구입       홍차
# 42     이미지        구입       수제      포푸리       선물
# 43      구입        라벨       홍차       영상       상자
# 44     포푸리        도배       선물     일러스트      스티커
# 45      영상       홍보지       상자       촬영      페인트
# 46    일러스트      수제홍차       내지      네이버       문서
# 47      촬영        홍차      스티커       서브      시스템
# 48     네이버        선물      페인트        메       코팅
# 49      서브      선물상자       안압      페이지       세트

# %% [markdown]
# ## 워드 클라우드 시각화

# %%
#워드클라우드
from wordcloud import WordCloud
feature_names = wc_okt['word_okt'].values
wcloud = WordCloud(font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',max_words=50, background_color='white', colormap = 'gist_heat')
wcloud.generate(' '.join(word for word in feature_names[:]))
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(wcloud)

# %%
#워드클라우드
from wordcloud import WordCloud
feature_names = wc_tk['word_tk'].values
wcloud = WordCloud(font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',max_words=50, background_color='white', colormap = 'gist_heat')
wcloud.generate(' '.join(word for word in feature_names[:]))
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(wcloud)

# %% [markdown]
# ##토픽추출 (TF-IDF, LDA)

# %% [markdown]
# ###라이브러리

# %%
#Libraries for preprocessing
#code from:https://towardsdatascience.com/clustering-product-names-with-python-part-1-f9418f8705c8
# %matplotlib inline
import plotly.express as px
from gensim.parsing.preprocessing import remove_stopwords
import string
from nltk.stem import PorterStemmer

# !pip install webcolors
import webcolors

#Download once if using NLTK for preprocessing
import nltk
nltk.download('punkt')

#Libraries for vectorisation
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV
# !pip install fuzzywuzzy
from fuzzywuzzy import fuzz

#Libraries for clustering
from sklearn.cluster import KMeans
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: webcolors in /usr/local/lib/python3.7/dist-packages (1.12)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.7/dist-packages (0.18.0)

# %% [markdown]
# ### okt 적용 텍스트

# %%
df['okt_noun_str'] = df['okt_noun'].apply(list_to_str)

# %%
df['okt_noun_str']
# Out:
# 0         영문 기사 작성
# 1        신문사 기사 발행
# 2           김치찌개 팩
# 3         블루베리 액기스
# 4            문서 작업
#           ...
# 396    양천구청 캐릭터 제작
# 397      미디어 예술 상회
# 398      미디어 예술 상회
# 399         방송 타이틀
# 400           관리 기
# Name: okt_noun_str, Length: 332, dtype: object

# %%
#okt 명사추출 열
text = df['okt_noun_str']

# %%
#bag of words
vectorizer_cv = CountVectorizer(analyzer='word')
X_cv = vectorizer_cv.fit_transform(text)

# %%
#TF-IDF (word level)
vectorizer_wtf = TfidfVectorizer(analyzer='word')
X_wtf = vectorizer_wtf.fit_transform(text)

# %%
#TF-IDF (n-gram level)
vectorizer_ntf = TfidfVectorizer(analyzer='word',ngram_range=(1,2))
X_ntf = vectorizer_ntf.fit_transform(text)

# %%
#LDA
lda = LatentDirichletAllocation(n_components=10, learning_decay=0.9)
X_lda = lda.fit(X_cv)

#Plot topics function. 
#Code from: https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html
def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(2, 5, figsize=(18, 6), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 15})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=15)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=10)
    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()
    
#Show topics
n_top_words = 3
feature_names = vectorizer_cv.get_feature_names()
plot_top_words(X_lda, feature_names, n_top_words, '')

# %% [markdown]
# ###한나눔 적용 텍스트

# %%
#한나눔 명사추출 열
df['han_noun_str'] = df['han_noun'].apply(list_to_str)

# %%
df['han_noun_str']
# Out:
# 0          영문기사 작성
# 1        신문사 기사 발행
# 2           김치찌개 팩
# 3         블루베리 액기스
# 4             문서작업
#           ...
# 396    양천구청 캐릭터 제작
# 397       미디어 예술상회
# 398       미디어 예술상회
# 399         방송 타이틀
# 400            관리기
# Name: han_noun_str, Length: 332, dtype: object

# %%
text = df['han_noun_str']

# %%
#bag of words
vectorizer_cv = CountVectorizer(analyzer='word')
X_cv = vectorizer_cv.fit_transform(text)

# %%
#LDA
lda = LatentDirichletAllocation(n_components=10, learning_decay=0.9)
X_lda = lda.fit(X_cv)

#Plot topics function. Code from: https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html
def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(2, 5, figsize=(18, 6), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 15})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=15)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=10)
    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()
    
#Show topics
n_top_words = 3
feature_names = vectorizer_cv.get_feature_names()
plot_top_words(X_lda, feature_names, n_top_words, '')
